# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import albumentations as A

from tensorflow.keras.layers import BatchNormalization

def unet_model(input_size=(256, 256, 1)):
    inputs = layers.Input(input_size)

    # Encoder (Downsampling)
    conv1 = layers.Conv2D(64, 3, activation='relu', padding='same')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = layers.Conv2D(64, 3, activation='relu', padding='same')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = layers.Conv2D(128, 3, activation='relu', padding='same')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = layers.Conv2D(128, 3, activation='relu', padding='same')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = layers.Conv2D(256, 3, activation='relu', padding='same')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = layers.Conv2D(256, 3, activation='relu', padding='same')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)

    # Bridge
    conv4 = layers.Conv2D(512, 3, activation='relu', padding='same')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = layers.Conv2D(512, 3, activation='relu', padding='same')(conv4)
    conv4 = BatchNormalization()(conv4)

    # Decoder (Upsampling)
    up5 = layers.UpSampling2D(size=(2, 2))(conv4)
    up5 = layers.concatenate([up5, conv3])
    conv5 = layers.Conv2D(256, 3, activation='relu', padding='same')(up5)
    conv5 = BatchNormalization()(conv5)
    conv5 = layers.Conv2D(256, 3, activation='relu', padding='same')(conv5)
    conv5 = BatchNormalization()(conv5)

    up6 = layers.UpSampling2D(size=(2, 2))(conv5)
    up6 = layers.concatenate([up6, conv2])
    conv6 = layers.Conv2D(128, 3, activation='relu', padding='same')(up6)
    conv6 = BatchNormalization()(conv6)
    conv6 = layers.Conv2D(128, 3, activation='relu', padding='same')(conv6)
    conv6 = BatchNormalization()(conv6)

    up7 = layers.UpSampling2D(size=(2, 2))(conv6)
    up7 = layers.concatenate([up7, conv1])
    conv7 = layers.Conv2D(64, 3, activation='relu', padding='same')(up7)
    conv7 = BatchNormalization()(conv7)
    conv7 = layers.Conv2D(64, 3, activation='relu', padding='same')(conv7)
    conv7 = BatchNormalization()(conv7)

    # Output layer (two channels: stamp and signature masks)
    outputs = layers.Conv2D(2, 1, activation='sigmoid')(conv7)

    model = models.Model(inputs=inputs, outputs=outputs)
    return model



# Separate Data Generator for Training and Validation
def data_generator(overlapped_dir, stamp_dir, signature_dir, batch_size=16, shuffle=True):
    overlapped_files = os.listdir(overlapped_dir)

    if shuffle:
        np.random.shuffle(overlapped_files)

    while True:
        batch_overlapped = []
        batch_stamps = []
        batch_signatures = []


        for _ in range(batch_size):
            idx = np.random.randint(0, len(overlapped_files))
            filename = overlapped_files[idx]

            overlapped_img_path = os.path.join(overlapped_dir, filename)
            stamp_img_path = os.path.join(stamp_dir, filename)
            signature_img_path = os.path.join(signature_dir, filename)

            # Check if files exist
            if not (os.path.exists(overlapped_img_path) and
                    os.path.exists(stamp_img_path) and
                    os.path.exists(signature_img_path)):
                continue  # Skip if any file is missing

            # Load images
            overlapped_img = tf.keras.utils.load_img(overlapped_img_path,
                                                     color_mode="grayscale",
                                                     target_size=(256, 256))
            stamp_img = tf.keras.utils.load_img(stamp_img_path,
                                                color_mode="grayscale",
                                                target_size=(256, 256))
            signature_img = tf.keras.utils.load_img(signature_img_path,
                                                    color_mode="grayscale",
                                                    target_size=(256, 256))

            # Convert to arrays
            overlapped_img = tf.keras.utils.img_to_array(overlapped_img) / 255.0
            stamp_img = tf.keras.utils.img_to_array(stamp_img) / 255.0
            signature_img = tf.keras.utils.img_to_array(signature_img) / 255.0

            batch_overlapped.append(overlapped_img)
            batch_stamps.append(stamp_img)
            batch_signatures.append(signature_img)

        # Combine stamps and signatures into a single output tensor
        batch_overlapped = np.array(batch_overlapped)
        batch_stamps_signatures = np.concatenate(
            [np.array(batch_stamps), np.array(batch_signatures)], axis=-1)

        yield batch_overlapped.astype(np.float32), batch_stamps_signatures.astype(np.float32)


# Paths to datasets
overlapped_dir = "/content/drive/MyDrive/ovp"
stamp_dir = "/content/drive/MyDrive/final/stamp_pre"
signature_dir = "/content/drive/MyDrive/final/signature_pre"


# Create and compile the model
model = unet_model()
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
              loss="binary_crossentropy",
              metrics=["accuracy"])

# Separate train and validation generators
train_gen = data_generator(overlapped_dir=overlapped_dir,
                           stamp_dir=stamp_dir,
                           signature_dir=signature_dir,
                           batch_size=16,
                           shuffle=True)

valid_gen = data_generator(overlapped_dir=overlapped_dir,
                           stamp_dir=stamp_dir,
                           signature_dir=signature_dir,
                           batch_size=16,
                           shuffle=False)  # No shuffle for validation

# Early stopping callback to prevent overfitting
early_stopping_cb = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5,
                                                      restore_best_weights=True)

lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, verbose=1)

# Train the model
history = model.fit(
    train_gen,
    steps_per_epoch=65,
    epochs=25,
    validation_data=valid_gen,
    validation_steps=20,
    callbacks=[early_stopping_cb, lr_scheduler]
)

# Save the trained model
model.save("stamp_signature_separator_2.h5")

# Plot training history
plt.figure(figsize=(10, 6))
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("Loss Over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# Function to predict and visualize results on a single image
def predict_and_visualize(model_path: str, image_path: str):
    # Load the trained model
    model_loaded = tf.keras.models.load_model(model_path)

    # Load and preprocess the input image
    img_original = tf.keras.utils.load_img(image_path,
                                           color_mode="grayscale",
                                           target_size=(256, 256))
    img_array = tf.keras.utils.img_to_array(img_original) / 255.0
    img_array_expanded = np.expand_dims(img_array.astype(np.float32), axis=0)

    # Predict the output masks (stamp and signature separation)
    prediction_masks = model_loaded.predict(img_array_expanded)

    # Visualize the results
    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(img_array.squeeze(), cmap="gray")
    plt.title("Input (Overlapped Image)")

    plt.subplot(1, 3, 2)
    plt.imshow(prediction_masks[0][:,:,0], cmap="gray")
    plt.title("Predicted Stamp Mask")

    plt.subplot(1, 3, 3)
    plt.imshow(prediction_masks[0][:,:,1], cmap="gray")
    plt.title("Predicted Signature Mask")

    plt.show()
# Out:
# Epoch 1/25
# 30/65 ━━━━━━━━━━━━━━━━━━━━ 1:07:42 116s/step - accuracy: 0.5983 - loss: 0.7138

# %%
model.save("stamp_signature_separator_2.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # Prediction

# %% [markdown]
# ## Preprocessing the given data

# %%
import cv2
import numpy as np
import os
from pathlib import Path

def preprocess_image(image_path, output_path):
    # Read the image in color
    img = cv2.imread(image_path)

    # Convert to LAB color space for better contrast handling
    lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)

    # Apply CLAHE (Contrast Limited Adaptive Histogram Equalization)
    # to enhance contrast smoothly
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    l_enhanced = clahe.apply(l)

    # Merge back with original color channels
    lab_enhanced = cv2.merge((l_enhanced, a, b))
    enhanced = cv2.cvtColor(lab_enhanced, cv2.COLOR_LAB2BGR)

    # Gentle sharpening using a smaller kernel
    gaussian = cv2.GaussianBlur(enhanced, (3,3), 0)
    sharpened = cv2.addWeighted(enhanced, 1.2, gaussian, -0.2, 0)

    # Enhance whiteness of background using a smooth curve
    # Create a lookup table to boost near-white values
    lut = np.array([min(255, int(255 * (x/255)**0.5)) if x > 200 else x
                   for x in range(256)], dtype=np.uint8)

    # Apply LUT to each channel
    result = sharpened.copy()
    for channel in range(3):
        result[:,:,channel] = cv2.LUT(sharpened[:,:,channel], lut)

    # Optional: Very light denoising to smooth edges
    result = cv2.fastNlMeansDenoisingColored(result, None, 5, 5, 7, 21)

    # Save the preprocessed image
    cv2.imwrite(output_path, result)

def main():
    # Input and output directories
    input_dir = r"/content/drive/MyDrive/images"
    output_dir = r"/content/drive/MyDrive/prepro"

    # Create output directory if it doesn't exist
    Path(output_dir).mkdir(parents=True, exist_ok=True)

    # Process all images in the input directory
    for filename in os.listdir(input_dir):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp')):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, f"preprocessed_{filename}")

            try:
                preprocess_image(input_path, output_path)
                print(f"Processed: {filename}")
            except Exception as e:
                print(f"Error processing {filename}: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Processed: signature_959_1.jpg
# Processed: stamp_528_1.jpg
# Processed: stamp_740_1.jpg
# Processed: signature_289_1.jpg
# Processed: stamp_492_1.jpg
# Processed: signature_246_1.jpg
# Processed: stamp_490_1.jpg
# Processed: stamp_314_1.jpg
# Processed: stamp_975_1.jpg
# Processed: signature_90_1.jpg
# Processed: stamp_780_1.jpg
# Processed: stamp_246_1.jpg
# Processed: stamp_99_1.jpg
# Processed: stamp_522_1.jpg
# Processed: stamp_201_1.jpg
# Processed: stamp_745_1.jpg
# Processed: signature_583_1.jpg
# Processed: stamp_45_1.jpg
# Processed: stamp_668_1.jpg
# Processed: signature_506_1.jpg
# Processed: signature_26_1.jpg
# Processed: signature_54_1.jpg
# Processed: stamp_40_1.jpg
# Processed: stamp_696_1.jpg
# Processed: stamp_23_1.jpg
# Processed: stamp_450_1.jpg
# Processed: signature_532_1.jpg
# Processed: stamp_17_1.jpg
# Processed: stamp_931_1.jpg
# Processed: stamp_639_1.jpg
# Processed: stamp_792_1.jpg
# Processed: signature_280_1.jpg
# Processed: stamp_458_1.jpg
# Processed: stamp_479_1.jpg
# Processed: signature_18_1.jpg
# Processed: signature_294_1.jpg
# Processed: signature_414_1.jpg
# Processed: stamp_727_1.jpg
# Processed: stamp_889_1.jpg
# Processed: stamp_214_1.jpg
# Processed: signature_293_1.jpg
# Processed: stamp_698_1.jpg
# Processed: stamp_238_1.jpg
# Processed: stamp_12_1.jpg
# Processed: signature_154_1.jpg
# Processed: stamp_928_1.jpg
# Processed: stamp_860_1.jpg
# Processed: signature_647_1.jpg
# Processed: stamp_927_1.jpg
# Processed: stamp_972_1.jpg
# Processed: stamp_880_1.jpg
# Processed: signature_257_1.jpg
# Processed: stamp_397_1.jpg
# Processed: stamp_474_1.jpg
# Processed: stamp_407_1.jpg
# Processed: signature_421_1.jpg
# Processed: stamp_315_1.jpg
# Processed: stamp_506_1.jpg
# Processed: signature_940_1.jpg
# Processed: stamp_578_1.jpg
# Processed: stamp_300_1.jpg
# Processed: signature_267_1.jpg
# Processed: stamp_451_1.jpg
# Processed: stamp_7_1.jpg
# Processed: stamp_833_1.jpg
# Processed: stamp_950_1.jpg
# Processed: stamp_256_1.jpg
# Processed: signature_725_1.jpg
# Processed: stamp_272_1.jpg
# Processed: signature_510_1.jpg
# Processed: signature_910_1.jpg
# Processed: stamp_255_1.jpg
# Processed: stamp_496_1.jpg
# Processed: stamp_174_1.jpg
# Processed: signature_460_1.jpg
# Processed: signature_254_1.jpg
# Processed: signature_310_1.jpg
# Processed: stamp_84_1.jpg
# Processed: stamp_898_1.jpg
# Processed: stamp_903_1.jpg
# Processed: stamp_626_1.jpg
# Processed: stamp_788_1.jpg
# Processed: stamp_61_1.jpg
# Processed: stamp_295_1.jpg
# Processed: signature_691_1.jpg
# Processed: stamp_440_1.jpg
# Processed: stamp_925_1.jpg
# Processed: stamp_96_1.jpg
# Processed: signature_726_1.jpg
# Processed: stamp_439_1.jpg
# Processed: signature_654_1.jpg
# Processed: signature_410_1.jpg
# Processed: stamp_764_1.jpg
# Processed: stamp_524_1.jpg
# Processed: signature_121_1.jpg
# Processed: signature_530_1.jpg
# Processed: stamp_851_1.jpg
# Processed: stamp_726_1.jpg
# Processed: stamp_181_1.jpg
# Processed: stamp_545_1.jpg
# Processed: signature_772_1.jpg
# Processed: signature_695_1.jpg
# Processed: stamp_337_1.jpg
# Processed: stamp_690_1.jpg
# Processed: signature_399_1.jpg
# Processed: stamp_9_1.jpg
# Processed: stamp_813_1.jpg
# Processed: stamp_102_1.jpg
# Processed: stamp_887_1.jpg
# Processed: stamp_24_1.jpg
# Processed: stamp_881_1.jpg
# Processed: stamp_355_1.jpg
# Processed: stamp_219_1.jpg
# Processed: stamp_229_1.jpg
# Processed: signature_636_1.jpg
# Processed: stamp_646_1.jpg
# Processed: stamp_362_1.jpg
# Processed: signature_40_1.jpg
# Processed: signature_416_1.jpg
# Processed: stamp_781_1.jpg
# Processed: stamp_308_1.jpg
# Processed: stamp_971_1.jpg
# Processed: stamp_945_1.jpg
# Processed: stamp_730_1.jpg
# Processed: stamp_660_1.jpg
# Processed: stamp_327_1.jpg
# Processed: signature_929_1.jpg
# Processed: signature_364_1.jpg
# Processed: stamp_202_1.jpg
# Processed: signature_435_1.jpg
# Processed: stamp_172_1.jpg
# Processed: signature_571_1.jpg
# Processed: stamp_485_1.jpg
# Processed: signature_589_1.jpg
# Processed: signature_514_1.jpg
# Processed: stamp_132_1.jpg
# Processed: stamp_33_1.jpg
# Processed: stamp_271_1.jpg
# Processed: stamp_358_1.jpg
# Processed: stamp_941_1.jpg
# Processed: stamp_26_1.jpg
# Processed: stamp_455_1.jpg
# Processed: stamp_640_1.jpg
# Processed: stamp_614_1.jpg
# Processed: stamp_236_1.jpg
# Processed: stamp_233_1.jpg
# Processed: stamp_297_1.jpg
# Processed: stamp_57_1.jpg
# Processed: stamp_976_1.jpg
# Processed: stamp_276_1.jpg
# Processed: signature_227_1.jpg
# Processed: stamp_340_1.jpg
# Processed: stamp_371_1.jpg
# Processed: stamp_366_1.jpg
# Processed: stamp_687_1.jpg
# Processed: signature_560_1.jpg
# Processed: signature_495_1.jpg
# Processed: stamp_104_1.jpg
# Processed: stamp_500_1.jpg
# Processed: stamp_139_1.jpg
# Processed: stamp_426_1.jpg
# Processed: stamp_147_1.jpg
# Processed: stamp_682_1.jpg
# Processed: signature_911_1.jpg
# Processed: stamp_182_1.jpg
# Processed: stamp_22_1.jpg
# Processed: stamp_421_1.jpg
# Processed: signature_59_1.jpg
# Processed: signature_600_1.jpg
# Processed: stamp_645_1.jpg
# Processed: stamp_386_1.jpg
# Processed: signature_386_1.jpg
# Processed: signature_794_1.jpg
# Processed: stamp_539_1.jpg
# Processed: stamp_627_1.jpg
# Processed: signature_614_1.jpg
# Processed: signature_286_1.jpg
# Processed: stamp_437_1.jpg
# Processed: stamp_879_1.jpg
# Processed: stamp_167_1.jpg
# Processed: stamp_866_1.jpg
# Processed: stamp_716_1.jpg
# Processed: signature_402_1.jpg
# Processed: signature_658_1.jpg
# Processed: signature_528_1.jpg
# Processed: stamp_51_1.jpg
# Processed: stamp_666_1.jpg
# Processed: stamp_943_1.jpg
# Processed: signature_932_1.jpg
# Processed: stamp_157_1.jpg
# Processed: stamp_791_1.jpg
# Processed: stamp_955_1.jpg
# Processed: stamp_319_1.jpg
# Processed: stamp_970_1.jpg
# Processed: stamp_20_1.jpg
# Processed: stamp_869_1.jpg
# Processed: stamp_59_1.jpg
# Processed: stamp_332_1.jpg
# Processed: stamp_82_1.jpg
# Processed: stamp_852_1.jpg
# Processed: signature_5_1.jpg
# Processed: signature_722_1.jpg
# Processed: stamp_729_1.jpg
# Processed: signature_879_1.jpg
# Processed: stamp_257_1.jpg
# Processed: stamp_357_1.jpg
# Processed: stamp_789_1.jpg
# Processed: signature_920_1.jpg
# Processed: stamp_504_1.jpg
# Processed: signature_258_1.jpg
# Processed: stamp_263_1.jpg
# Processed: stamp_472_1.jpg
# Processed: stamp_609_1.jpg
# Processed: signature_389_1.jpg
# Processed: stamp_814_1.jpg
# Processed: stamp_691_1.jpg
# Processed: stamp_904_1.jpg
# Processed: signature_926_1.jpg
# Processed: stamp_70_1.jpg
# Processed: signature_625_1.jpg
# Processed: signature_745_1.jpg
# Processed: stamp_145_1.jpg
# Processed: stamp_613_1.jpg
# Processed: stamp_532_1.jpg
# Processed: signature_950_1.jpg
# Processed: signature_318_1.jpg
# Processed: stamp_739_1.jpg
# Processed: stamp_405_1.jpg
# Processed: stamp_205_1.jpg
# Processed: signature_518_1.jpg
# Processed: stamp_755_1.jpg
# Processed: signature_893_1.jpg
# Processed: stamp_153_1.jpg
# Processed: stamp_50_1.jpg
# Processed: stamp_114_1.jpg
# Processed: stamp_203_1.jpg
# Processed: stamp_360_1.jpg
# Processed: stamp_170_1.jpg
# Processed: stamp_821_1.jpg
# Processed: signature_233_1.jpg
# Processed: stamp_42_1.jpg
# Processed: stamp_969_1.jpg
# Processed: stamp_301_1.jpg
# Processed: signature_517_1.jpg
# Processed: signature_250_1.jpg
# Processed: signature_131_1.jpg
# Processed: stamp_837_1.jpg
# Processed: stamp_66_1.jpg
# Processed: stamp_994_1.jpg
# Processed: signature_782_1.jpg
# Processed: stamp_191_1.jpg
# Processed: stamp_135_1.jpg
# Processed: signature_566_1.jpg
# Processed: stamp_786_1.jpg
# Processed: signature_160_1.jpg
# Processed: stamp_71_1.jpg
# Processed: stamp_427_1.jpg
# Processed: stamp_311_1.jpg
# Processed: stamp_21_1.jpg
# Processed: stamp_432_1.jpg
# Processed: signature_814_1.jpg
# Processed: stamp_322_1.jpg
# Processed: stamp_549_1.jpg
# Processed: signature_898_1.jpg
# Processed: stamp_916_1.jpg
# Processed: stamp_379_1.jpg
# Processed: stamp_471_1.jpg
# Processed: stamp_987_1.jpg
# Processed: stamp_574_1.jpg
# Processed: stamp_744_1.jpg
# Processed: stamp_190_1.jpg
# Processed: stamp_100_1.jpg
# Processed: stamp_625_1.jpg
# Processed: stamp_13_1.jpg
# Processed: stamp_560_1.jpg
# Processed: stamp_865_1.jpg
# Processed: stamp_650_1.jpg
# Processed: stamp_517_1.jpg
# Processed: stamp_5_1.jpg
# Processed: signature_88_1.jpg
# Processed: signature_412_1.jpg
# Processed: stamp_602_1.jpg
# Processed: stamp_653_1.jpg
# Processed: stamp_34_1.jpg
# Processed: signature_360_1.jpg
# Processed: stamp_637_1.jpg
# Processed: signature_143_1.jpg
# Processed: stamp_68_1.jpg
# Processed: signature_572_1.jpg
# Processed: stamp_141_1.jpg
# Processed: signature_549_1.jpg
# Processed: stamp_306_1.jpg
# Processed: signature_750_1.jpg
# Processed: stamp_909_1.jpg
# Processed: stamp_460_1.jpg
# Processed: stamp_534_1.jpg
# Processed: stamp_335_1.jpg
# Processed: stamp_275_1.jpg
# Processed: stamp_977_1.jpg
# Processed: signature_182_1.jpg
# Processed: stamp_510_1.jpg
# Processed: signature_672_1.jpg
# Processed: stamp_514_1.jpg
# Processed: stamp_990_1.jpg
# Processed: stamp_825_1.jpg
# Processed: stamp_874_1.jpg
# Processed: signature_207_1.jpg
# Processed: stamp_601_1.jpg
# Processed: signature_63_1.jpg
# Processed: signature_900_1.jpg
# Processed: stamp_633_1.jpg
# Processed: signature_150_1.jpg
# Processed: stamp_844_1.jpg
# Processed: signature_930_1.jpg
# Processed: signature_483_1.jpg
# Processed: stamp_328_1.jpg
# Processed: stamp_1000_1.jpg
# Processed: stamp_318_1.jpg
# Processed: stamp_924_1.jpg
# Processed: stamp_75_1.jpg
# Processed: signature_892_1.jpg
# Processed: stamp_359_1.jpg
# Processed: stamp_542_1.jpg
# Processed: signature_203_1.jpg
# Processed: signature_616_1.jpg
# Processed: stamp_274_1.jpg
# Processed: stamp_262_1.jpg
# Processed: signature_420_1.jpg
# Processed: stamp_467_1.jpg
# Processed: stamp_137_1.jpg
# Processed: stamp_118_1.jpg
# Processed: stamp_85_1.jpg
# Processed: stamp_151_1.jpg
# Processed: signature_13_1.jpg
# Processed: signature_214_1.jpg
# Processed: signature_891_1.jpg
# Processed: signature_52_1.jpg
# Processed: stamp_885_1.jpg
# Processed: stamp_123_1.jpg
# Processed: stamp_817_1.jpg
# Processed: signature_619_1.jpg
# Processed: stamp_73_1.jpg
# Processed: stamp_926_1.jpg
# Processed: stamp_536_1.jpg
# Processed: stamp_920_1.jpg
# Processed: stamp_954_1.jpg
# Processed: stamp_622_1.jpg
# Processed: stamp_829_1.jpg
# Processed: stamp_241_1.jpg
# Processed: stamp_894_1.jpg
# Processed: stamp_278_1.jpg
# Processed: stamp_861_1.jpg
# Processed: stamp_673_1.jpg
# Processed: stamp_686_1.jpg
# Processed: stamp_420_1.jpg
# Processed: signature_401_1.jpg
# Processed: stamp_676_1.jpg
# Processed: signature_694_1.jpg
# Processed: signature_197_1.jpg
# Processed: stamp_400_1.jpg
# Processed: stamp_115_1.jpg
# Processed: stamp_579_1.jpg
# Processed: stamp_169_1.jpg
# Processed: signature_889_1.jpg
# Processed: stamp_382_1.jpg
# Processed: stamp_872_1.jpg
# Processed: stamp_364_1.jpg
# Processed: signature_871_1.jpg
# Processed: stamp_888_1.jpg
# Processed: stamp_89_1.jpg
# Processed: signature_492_1.jpg
# Processed: stamp_198_1.jpg
# Processed: stamp_799_1.jpg
# Processed: signature_27_1.jpg
# Processed: signature_438_1.jpg
# Processed: stamp_46_1.jpg
# Processed: stamp_923_1.jpg
# Processed: stamp_31_1.jpg
# Processed: stamp_56_1.jpg
# Processed: stamp_621_1.jpg
# Processed: stamp_763_1.jpg
# Processed: signature_46_1.jpg
# Processed: stamp_179_1.jpg
# Processed: stamp_347_1.jpg
# Processed: stamp_283_1.jpg
# Processed: stamp_772_1.jpg
# Processed: stamp_680_1.jpg
# Processed: stamp_223_1.jpg
# Processed: stamp_152_1.jpg
# Processed: stamp_610_1.jpg
# Processed: stamp_830_1.jpg
# Processed: stamp_804_1.jpg
# Processed: stamp_116_1.jpg
# Processed: stamp_393_1.jpg
# Processed: stamp_962_1.jpg
# Processed: signature_363_1.jpg
# Processed: stamp_381_1.jpg
# Processed: stamp_695_1.jpg
# Processed: stamp_953_1.jpg
# Processed: stamp_247_1.jpg
# Processed: signature_328_1.jpg
# Processed: stamp_339_1.jpg
# Processed: signature_868_1.jpg
# Processed: stamp_470_1.jpg
# Processed: stamp_466_1.jpg
# Processed: signature_291_1.jpg
# Processed: stamp_106_1.jpg
# Processed: signature_788_1.jpg
# Processed: stamp_95_1.jpg
# Processed: stamp_74_1.jpg
# Processed: stamp_134_1.jpg
# Processed: stamp_527_1.jpg
# Processed: stamp_105_1.jpg
# Processed: signature_470_1.jpg
# Processed: signature_544_1.jpg
# Processed: stamp_204_1.jpg
# Processed: stamp_194_1.jpg
# Processed: stamp_576_1.jpg
# Processed: stamp_94_1.jpg
# Processed: stamp_794_1.jpg
# Processed: stamp_675_1.jpg
# Processed: stamp_266_1.jpg
# Processed: stamp_577_1.jpg
# Processed: signature_767_1.jpg
# Processed: signature_523_1.jpg
# Processed: stamp_67_1.jpg
# Processed: signature_905_1.jpg
# Processed: stamp_140_1.jpg
# Processed: stamp_413_1.jpg
# Processed: signature_646_1.jpg
# Processed: signature_811_1.jpg
# Processed: stamp_268_1.jpg
# Processed: signature_648_1.jpg
# Processed: stamp_505_1.jpg
# Processed: signature_62_1.jpg
# Processed: signature_152_1.jpg
# Processed: stamp_378_1.jpg
# Processed: signature_969_1.jpg
# Processed: signature_525_1.jpg
# Processed: signature_760_1.jpg
# Processed: stamp_823_1.jpg
# Processed: stamp_585_1.jpg
# Processed: stamp_588_1.jpg
# Processed: stamp_302_1.jpg
# Processed: signature_424_1.jpg
# Processed: stamp_612_1.jpg
# Processed: stamp_447_1.jpg
# Processed: stamp_993_1.jpg
# Processed: signature_135_1.jpg
# Processed: signature_325_1.jpg
# Processed: signature_183_1.jpg
# Processed: stamp_838_1.jpg
# Processed: signature_73_1.jpg
# Processed: stamp_53_1.jpg
# Processed: stamp_375_1.jpg
# Processed: stamp_647_1.jpg
# Processed: signature_377_1.jpg
# Processed: stamp_227_1.jpg
# Processed: signature_202_1.jpg
# Processed: stamp_930_1.jpg
# Processed: stamp_905_1.jpg
# Processed: stamp_259_1.jpg
# Processed: stamp_207_1.jpg
# Processed: stamp_871_1.jpg
# Processed: stamp_79_1.jpg
# Processed: stamp_78_1.jpg
# Processed: stamp_433_1.jpg
# Processed: stamp_884_1.jpg
# Processed: stamp_777_1.jpg
# Processed: stamp_538_1.jpg
# Processed: signature_255_1.jpg
# Processed: signature_297_1.jpg
# Processed: signature_367_1.jpg
# Processed: stamp_323_1.jpg
# Processed: stamp_850_1.jpg
# Processed: stamp_442_1.jpg
# Processed: signature_47_1.jpg
# Processed: stamp_790_1.jpg
# Processed: stamp_986_1.jpg
# Processed: signature_864_1.jpg
# Processed: stamp_18_1.jpg
# Processed: signature_641_1.jpg
# Processed: signature_165_1.jpg
# Processed: stamp_76_1.jpg
# Processed: stamp_596_1.jpg
# Processed: stamp_543_1.jpg
# Processed: signature_279_1.jpg
# Processed: stamp_603_1.jpg
# Processed: stamp_465_1.jpg
# Processed: stamp_910_1.jpg
# Processed: stamp_497_1.jpg
# Processed: stamp_834_1.jpg
# Processed: signature_439_1.jpg
# Processed: stamp_669_1.jpg
# Processed: signature_394_1.jpg
# Processed: signature_954_1.jpg
# Processed: stamp_802_1.jpg
# Processed: stamp_224_1.jpg
# Processed: stamp_843_1.jpg
# Processed: signature_237_1.jpg
# Processed: signature_828_1.jpg
# Processed: stamp_737_1.jpg
# Processed: stamp_559_1.jpg
# Processed: stamp_584_1.jpg
# Processed: stamp_326_1.jpg
# Processed: stamp_757_1.jpg
# Processed: stamp_974_1.jpg
# Processed: signature_508_1.jpg
# Processed: signature_353_1.jpg
# Processed: signature_971_1.jpg
# Processed: stamp_949_1.jpg
# Processed: stamp_189_1.jpg
# Processed: signature_809_1.jpg
# Processed: signature_639_1.jpg
# Processed: signature_768_1.jpg
# Processed: signature_464_1.jpg
# Processed: signature_372_1.jpg
# Processed: stamp_399_1.jpg
# Processed: stamp_664_1.jpg
# Processed: stamp_416_1.jpg
# Processed: stamp_35_1.jpg
# Processed: stamp_784_1.jpg
# Processed: stamp_870_1.jpg
# Processed: stamp_743_1.jpg
# Processed: stamp_248_1.jpg
# Processed: stamp_868_1.jpg
# Processed: signature_818_1.jpg
# Processed: signature_87_1.jpg
# Processed: signature_415_1.jpg
# Processed: stamp_333_1.jpg
# Processed: stamp_212_1.jpg
# Processed: stamp_768_1.jpg
# Processed: signature_204_1.jpg
# Processed: signature_490_1.jpg
# Processed: stamp_854_1.jpg
# Processed: stamp_708_1.jpg
# Processed: stamp_185_1.jpg
# Processed: signature_901_1.jpg
# Processed: signature_668_1.jpg
# Processed: signature_925_1.jpg
# Processed: stamp_734_1.jpg
# Processed: stamp_568_1.jpg
# Processed: signature_717_1.jpg
# Processed: stamp_566_1.jpg
# Processed: stamp_587_1.jpg
# Processed: signature_802_1.jpg
# Processed: stamp_482_1.jpg
# Processed: stamp_261_1.jpg
# Processed: signature_870_1.jpg
# Processed: stamp_940_1.jpg
# Processed: signature_558_1.jpg
# Processed: stamp_409_1.jpg
# Processed: stamp_619_1.jpg
# Processed: stamp_796_1.jpg
# Processed: stamp_983_1.jpg
# Processed: stamp_80_1.jpg
# Processed: signature_50_1.jpg
# Processed: signature_181_1.jpg
# Processed: signature_58_1.jpg
# Processed: signature_730_1.jpg
# Processed: stamp_461_1.jpg
# Processed: signature_110_1.jpg
# Processed: stamp_128_1.jpg
# Processed: stamp_37_1.jpg
# Processed: stamp_367_1.jpg
# Processed: stamp_547_1.jpg
# Processed: stamp_119_1.jpg
# Processed: stamp_774_1.jpg
# Processed: signature_710_1.jpg
# Processed: signature_578_1.jpg
# Processed: stamp_343_1.jpg
# Processed: stamp_914_1.jpg
# Processed: stamp_546_1.jpg
# Processed: stamp_27_1.jpg
# Processed: stamp_773_1.jpg
# Processed: stamp_741_1.jpg
# Processed: signature_551_1.jpg
# Processed: stamp_526_1.jpg
# Processed: stamp_422_1.jpg
# Processed: stamp_807_1.jpg
# Processed: stamp_404_1.jpg
# Processed: stamp_383_1.jpg
# Processed: signature_216_1.jpg
# Processed: stamp_685_1.jpg
# Processed: stamp_615_1.jpg
# Processed: signature_15_1.jpg
# Processed: stamp_97_1.jpg
# Processed: stamp_965_1.jpg
# Processed: stamp_155_1.jpg
# Processed: stamp_548_1.jpg
# Processed: stamp_220_1.jpg
# Processed: stamp_782_1.jpg
# Processed: signature_799_1.jpg
# Processed: signature_526_1.jpg
# Processed: signature_626_1.jpg
# Processed: signature_103_1.jpg
# Processed: stamp_243_1.jpg
# Processed: stamp_630_1.jpg
# Processed: stamp_775_1.jpg
# Processed: stamp_108_1.jpg
# Processed: stamp_486_1.jpg
# Processed: stamp_401_1.jpg
# Processed: stamp_289_1.jpg
# Processed: stamp_563_1.jpg
# Processed: stamp_644_1.jpg
# Processed: stamp_65_1.jpg
# Processed: stamp_464_1.jpg
# Processed: stamp_161_1.jpg
# Processed: stamp_557_1.jpg
# Processed: stamp_902_1.jpg
# Processed: stamp_515_1.jpg
# Processed: signature_734_1.jpg
# Processed: stamp_582_1.jpg
# Processed: stamp_443_1.jpg
# Processed: stamp_136_1.jpg
# Processed: signature_623_1.jpg
# Processed: stamp_280_1.jpg
# Processed: stamp_803_1.jpg
# Processed: stamp_984_1.jpg
# Processed: stamp_369_1.jpg
# Processed: stamp_38_1.jpg
# Processed: signature_51_1.jpg
# Processed: stamp_270_1.jpg
# Processed: signature_553_1.jpg
# Processed: signature_848_1.jpg
# Processed: signature_441_1.jpg
# Processed: stamp_183_1.jpg
# Processed: stamp_406_1.jpg
# Processed: stamp_200_1.jpg
# Processed: signature_501_1.jpg
# Processed: signature_357_1.jpg
# Processed: stamp_819_1.jpg
# Processed: signature_824_1.jpg
# Processed: signature_67_1.jpg
# Processed: stamp_149_1.jpg
# Processed: signature_587_1.jpg
# Processed: signature_371_1.jpg
# Processed: stamp_387_1.jpg
# Processed: stamp_604_1.jpg
# Processed: signature_118_1.jpg
# Processed: stamp_208_1.jpg
# Processed: stamp_594_1.jpg
# Processed: stamp_663_1.jpg
# Processed: stamp_701_1.jpg
# Processed: stamp_623_1.jpg
# Processed: stamp_728_1.jpg
# Processed: stamp_122_1.jpg
# Processed: stamp_54_1.jpg
# Processed: stamp_159_1.jpg
# Processed: stamp_431_1.jpg
# Processed: stamp_779_1.jpg
# Processed: stamp_279_1.jpg
# Processed: stamp_144_1.jpg
# Processed: signature_585_1.jpg
# Processed: stamp_785_1.jpg
# Processed: stamp_521_1.jpg
# Processed: stamp_434_1.jpg
# Processed: stamp_481_1.jpg
# Processed: stamp_150_1.jpg
# Processed: stamp_463_1.jpg
# Processed: signature_992_1.jpg
# Processed: signature_974_1.jpg
# Processed: signature_180_1.jpg
# Processed: stamp_162_1.jpg
# Processed: stamp_15_1.jpg
# Processed: stamp_231_1.jpg
# Processed: stamp_758_1.jpg
# Processed: signature_895_1.jpg
# Processed: signature_176_1.jpg
# Processed: stamp_109_1.jpg
# Processed: stamp_237_1.jpg
# Processed: stamp_325_1.jpg
# Processed: stamp_346_1.jpg
# Processed: stamp_911_1.jpg
# Processed: stamp_394_1.jpg
# Processed: signature_673_1.jpg
# Processed: stamp_934_1.jpg
# Processed: signature_463_1.jpg
# Processed: stamp_146_1.jpg
# Processed: signature_136_1.jpg
# Processed: signature_68_1.jpg
# Processed: stamp_996_1.jpg
# Processed: stamp_98_1.jpg
# Processed: signature_434_1.jpg
# Processed: stamp_628_1.jpg
# Processed: signature_407_1.jpg
# Processed: signature_743_1.jpg
# Processed: signature_341_1.jpg
# Processed: stamp_767_1.jpg
# Processed: stamp_810_1.jpg
# Processed: stamp_494_1.jpg
# Processed: stamp_770_1.jpg
# Processed: stamp_883_1.jpg
# Processed: stamp_277_1.jpg
# Processed: signature_746_1.jpg
# Processed: signature_321_1.jpg
# Processed: stamp_806_1.jpg
# Processed: signature_151_1.jpg
# Processed: signature_692_1.jpg
# Processed: signature_205_1.jpg
# Processed: stamp_787_1.jpg
# Processed: signature_66_1.jpg
# Processed: signature_876_1.jpg
# Processed: stamp_120_1.jpg
# Processed: signature_765_1.jpg
# Processed: stamp_158_1.jpg
# Processed: stamp_291_1.jpg
# Processed: signature_841_1.jpg
# Processed: signature_395_1.jpg
# Processed: stamp_48_1.jpg
# Processed: signature_923_1.jpg
# Processed: stamp_113_1.jpg
# Processed: stamp_751_1.jpg
# Processed: stamp_723_1.jpg
# Processed: stamp_845_1.jpg
# Processed: signature_783_1.jpg
# Processed: signature_127_1.jpg
# Processed: stamp_938_1.jpg
# Processed: stamp_966_1.jpg
# Processed: stamp_349_1.jpg
# Processed: signature_368_1.jpg
# Processed: signature_427_1.jpg
# Processed: stamp_681_1.jpg
# Processed: signature_133_1.jpg
# Processed: signature_147_1.jpg
# Processed: stamp_3_1.jpg
# Processed: stamp_697_1.jpg
# Processed: signature_20_1.jpg
# Processed: stamp_317_1.jpg
# Processed: signature_644_1.jpg
# Processed: stamp_125_1.jpg
# Processed: stamp_797_1.jpg
# Processed: stamp_390_1.jpg
# Processed: stamp_217_1.jpg
# Processed: signature_653_1.jpg
# Processed: stamp_875_1.jpg
# Processed: stamp_960_1.jpg
# Processed: stamp_570_1.jpg
# Processed: signature_472_1.jpg
# Processed: stamp_63_1.jpg
# Processed: signature_676_1.jpg
# Processed: signature_781_1.jpg
# Processed: stamp_616_1.jpg
# Processed: stamp_815_1.jpg
# Processed: stamp_693_1.jpg
# Processed: stamp_558_1.jpg
# Processed: stamp_679_1.jpg
# Processed: signature_739_1.jpg
# Processed: stamp_345_1.jpg
# Processed: signature_752_1.jpg
# Processed: stamp_415_1.jpg
# Processed: stamp_354_1.jpg
# Processed: stamp_438_1.jpg
# Processed: signature_451_1.jpg
# Processed: signature_71_1.jpg
# Processed: stamp_503_1.jpg
# Processed: stamp_657_1.jpg
# Processed: stamp_72_1.jpg
# Processed: stamp_995_1.jpg
# Processed: signature_540_1.jpg
# Processed: stamp_771_1.jpg
# Processed: stamp_126_1.jpg
# Processed: stamp_489_1.jpg
# Processed: stamp_853_1.jpg
# Processed: signature_784_1.jpg
# Processed: stamp_16_1.jpg
# Processed: stamp_166_1.jpg
# Processed: stamp_725_1.jpg
# Processed: stamp_978_1.jpg
# Processed: stamp_873_1.jpg
# Processed: stamp_567_1.jpg
# Processed: stamp_28_1.jpg
# Processed: stamp_826_1.jpg
# Processed: stamp_900_1.jpg
# Processed: signature_161_1.jpg
# Processed: signature_104_1.jpg
# Processed: signature_383_1.jpg
# Processed: signature_298_1.jpg
# Processed: signature_620_1.jpg
# Processed: signature_663_1.jpg
# Processed: stamp_717_1.jpg
# Processed: stamp_533_1.jpg
# Processed: signature_175_1.jpg
# Processed: signature_93_1.jpg
# Processed: stamp_269_1.jpg
# Processed: stamp_967_1.jpg
# Processed: stamp_968_1.jpg
# Processed: stamp_192_1.jpg
# Processed: signature_146_1.jpg
# Processed: stamp_19_1.jpg
# Processed: stamp_30_1.jpg
# Processed: signature_408_1.jpg
# Processed: stamp_581_1.jpg
# Processed: stamp_39_1.jpg
# Processed: stamp_58_1.jpg
# Processed: stamp_286_1.jpg
# Processed: stamp_142_1.jpg
# Processed: stamp_800_1.jpg
# Processed: stamp_551_1.jpg
# Processed: signature_76_1.jpg
# Processed: signature_228_1.jpg
# Processed: signature_450_1.jpg
# Processed: signature_859_1.jpg
# Processed: stamp_842_1.jpg
# Processed: signature_810_1.jpg

# %% [markdown]
# ## Convert to grayscale

# %%
import os
import cv2  # OpenCV for image processing

# Define input and output directories
input_dir = "/content/drive/MyDrive/prepro"  # Replace with your input folder path
output_dir = "/content/drive/MyDrive/prepro_grayscale"  # Replace with your output folder path

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Process each image in the input directory
for filename in os.listdir(input_dir):
    input_path = os.path.join(input_dir, filename)

    # Check if it's an image file (optional, avoids errors on non-image files)
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
        # Read the image
        img = cv2.imread(input_path)

        if img is not None:
            # Convert to grayscale
            gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            # Save the grayscale image
            output_path = os.path.join(output_dir, filename)
            cv2.imwrite(output_path, gray_img)

print("Conversion complete! Grayscale images saved in:", output_dir)
# Out:
# Conversion complete! Grayscale images saved in: /content/drive/MyDrive/prepro_grayscale

# %% [markdown]
# ## Result

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

def predict_and_visualize(model_path: str, image_path: str):
    """
    Loads the trained U-Net model and predicts stamp and signature masks on a given image.

    Args:
        model_path (str): Path to the saved model (.h5 file).
        image_path (str): Path to the input image.

    Returns:
        None (Displays the original image and predicted masks)
    """
    # Load the trained model
    model_loaded = tf.keras.models.load_model(model_path)

    # Load and preprocess the input image
    img_original = tf.keras.utils.load_img(image_path,
                                           color_mode="grayscale",
                                           target_size=(256, 256))
    img_array = tf.keras.utils.img_to_array(img_original) / 255.0  # Normalize
    img_array_expanded = np.expand_dims(img_array.astype(np.float32), axis=0)  # Add batch dimension

    # Predict the output masks (stamp and signature separation)
    prediction_masks = model_loaded.predict(img_array_expanded)[0]  # Get first prediction

    # Visualize the results
    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(img_array.squeeze(), cmap="gray")
    plt.title("Input (Overlapped Image)")

    plt.subplot(1, 3, 2)
    plt.imshow(prediction_masks[:, :, 0], cmap="gray")
    plt.title("Predicted Stamp Mask")

    plt.subplot(1, 3, 3)
    plt.imshow(prediction_masks[:, :, 1], cmap="gray")
    plt.title("Predicted Signature Mask")

    plt.show()


predict_and_visualize("/content/drive/MyDrive/stamp_signature_separator_2.h5", "/content/drive/MyDrive/overlap/118.png")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %% [markdown]
# # Again dataset

# %%
import cv2
import os

# Paths to your datasets
stamp_folder = r'/content/drive/MyDrive/final/stamp_pre'  # Replace with the actual path to your stamp folder
signature_folder = r'/content/drive/MyDrive/final/signature_pre'  # Replace with the actual path to your signature folder
output_folder = r'/content/drive/MyDrive/overlap'  # Replace with the actual path to your output folder

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Load image paths and sort them to ensure corresponding files match
stamp_paths = sorted([os.path.join(stamp_folder, file) for file in os.listdir(stamp_folder) if file.endswith('.png')])
signature_paths = sorted([os.path.join(signature_folder, file) for file in os.listdir(signature_folder) if file.endswith('.png')])

# Ensure both folders have the same number of images
if len(stamp_paths) != len(signature_paths):
    raise ValueError('The number of images in both folders must be the same.')

# Overlay corresponding images
for stamp_path, signature_path in zip(stamp_paths, signature_paths):
    # Load images in grayscale
    stamp_image = cv2.imread(stamp_path, cv2.IMREAD_GRAYSCALE)
    signature_image = cv2.imread(signature_path, cv2.IMREAD_GRAYSCALE)

    # Ensure both images are the same size
    if stamp_image.shape != signature_image.shape:
        signature_image = cv2.resize(signature_image, (stamp_image.shape[1], stamp_image.shape[0]))

    # Overlay images with equal weight (50% transparency each)
    overlaid_image = cv2.addWeighted(stamp_image, 0.5, signature_image, 0.5, 0)

    # Save the overlaid image to the output folder
    filename = os.path.basename(stamp_path)
    output_path = os.path.join(output_folder, filename)
    cv2.imwrite(output_path, overlaid_image)

print(f"Overlay process completed. Overlaid images are saved in: {output_folder}")
# Out:
# Overlay process completed. Overlaid images are saved in: /content/drive/MyDrive/overlap

# %% [markdown]
# ## Save model to Gdrive

# %%
# !mv /content/stamp_signature_separator_2.h5 /content/drive/MyDrive/

# %% [markdown]
# # Result on image batch

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os
from tensorflow.keras.preprocessing.image import load_img, img_to_array

def batch_predict_and_save(model_path: str, input_folder: str, output_folder: str):
    """
    Loads a trained U-Net model and predicts masks for all images in a folder.
    Saves the predicted masks to an output folder.

    Args:
        model_path (str): Path to the saved model (.h5 file).
        input_folder (str): Path to the folder containing input images.
        output_folder (str): Path to save the predicted output images.

    Returns:
        None
    """
    # Load the trained model
    model_loaded = tf.keras.models.load_model(model_path)

    # Ensure output directory exists
    os.makedirs(output_folder, exist_ok=True)

    # Get list of images
    image_files = [f for f in os.listdir(input_folder) if f.endswith(('.jpg', '.png', '.jpeg'))]
    image_files = image_files[:100]  # Process only 20 images

    for img_name in image_files:
        img_path = os.path.join(input_folder, img_name)
        img_original = load_img(img_path, color_mode="grayscale", target_size=(256, 256))
        img_array = img_to_array(img_original) / 255.0  # Normalize
        img_array_expanded = np.expand_dims(img_array.astype(np.float32), axis=0)  # Add batch dimension

        # Predict the masks
        prediction_masks = model_loaded.predict(img_array_expanded)[0]  # Get first prediction

        # Save the masks
        stamp_mask = prediction_masks[:, :, 0]
        signature_mask = prediction_masks[:, :, 1]

        plt.imsave(os.path.join(output_folder, f"stamp_mask_{img_name}"), stamp_mask, cmap="gray")
        plt.imsave(os.path.join(output_folder, f"signature_mask_{img_name}"), signature_mask, cmap="gray")

    print(f"Processed {len(image_files)} images. Outputs saved in {output_folder}")

# Define paths
model_path = "/content/drive/MyDrive/stamp_signature_separator_2.h5"
input_folder = "/content/drive/MyDrive/prepro_grayscale"
output_folder = "/content/drive/MyDrive/output2/"

# Run batch processing
batch_predict_and_save(model_path, input_folder, output_folder)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Processed 100 images. Outputs saved in /content/drive/MyDrive/output2/

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

def predict_and_visualize(model_path: str, image_path: str, threshold: float = 0.5):
    """
    Loads the trained U-Net model and predicts stamp and signature masks on a given image.
    Applies thresholding to generate binary masks.

    Args:
        model_path (str): Path to the saved model (.h5 file).
        image_path (str): Path to the input image.
        threshold (float): Threshold for binarizing the predicted masks.

    Returns:
        None (Displays the original image and binary masks)
    """
    # Load the trained model
    model_loaded = tf.keras.models.load_model(model_path)

    # Load and preprocess the input image
    img_original = tf.keras.utils.load_img(image_path, color_mode="grayscale", target_size=(256, 256))
    img_array = tf.keras.utils.img_to_array(img_original) / 255.0  # Normalize
    img_array_expanded = np.expand_dims(img_array.astype(np.float32), axis=0)  # Add batch dimension

    # Predict the output masks
    prediction_masks = model_loaded.predict(img_array_expanded)[0]  # Get first prediction

    # Apply binary thresholding
    stamp_mask = np.where(prediction_masks[:, :, 0] >= threshold, 1.0, 0.0)  # Stamp mask (black & white)
    signature_mask = np.where(prediction_masks[:, :, 1] >= threshold, 1.0, 0.0)  # Signature mask (black & white)

    # Visualize the results
    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(img_array.squeeze(), cmap="gray")
    plt.title("Input (Overlapped Image)")

    plt.subplot(1, 3, 2)
    plt.imshow(stamp_mask, cmap="gray")
    plt.title("Binary Stamp Mask")

    plt.subplot(1, 3, 3)
    plt.imshow(signature_mask, cmap="gray")
    plt.title("Binary Signature Mask")

    plt.show()

# Run the function with your model and image
predict_and_visualize("/content/drive/MyDrive/stamp_signature_separator_2.h5",
                      "/content/drive/MyDrive/ovp/1.png")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
